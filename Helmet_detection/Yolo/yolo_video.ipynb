# %%
import torch

if torch.cuda.is_available():    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla P100-PCIE-16GB

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Yolo/yolov5'

# %%
# %cd drive/MyDrive/Colab Notebooks/Yolo/yolov5
# Out:
# /content/drive/MyDrive/Colab Notebooks/Yolo/yolov5

# %%
from glob import glob
from sklearn.model_selection import train_test_split
import yaml
from IPython.core.magic import register_line_cell_magic

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 5.1 MB/s

# %%
import torch
from IPython.display import Image, clear_output

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
from IPython.display import Image, display

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction1.mp4
# Out:
# ...
# detect: weights=['runs/train/hardhat_results2/weights/best.pt'], source=./video/construction1.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2815) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction1.mp4: 672x1280 1 helmet, Done. (0.019s)
# video 1/1 (2/2815) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction1.mp4: 672x1280 1 helmet, Done. (0.012s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction2.mp4
# Out:
# detect: weights=['runs/train/hardhat_results2/weights/best.pt'], source=./video/construction2.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3417) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction2.mp4: 672x1280 1 helmet, Done. (0.025s)
# video 1/1 (2/3417) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction2.mp4: 672x1280 1 helmet, Done. (0.011s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/constructionc3.mp4
# Out:
# detect: weights=['runs/train/hardhat_results2/weights/best.pt'], source=./video/constructionc3.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4267) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/constructionc3.mp4: 672x1280 10 heads, Done. (0.018s)
# video 1/1 (2/4267) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/constructionc3.mp4: 672x1280 10 heads, Done. (0.018s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction4.mp4
# Out:
# detect: weights=['runs/train/hardhat_results2/weights/best.pt'], source=./video/construction4.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4363) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction4.mp4: 672x1280 Done. (0.019s)
# video 1/1 (2/4363) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction4.mp4: 672x1280 Done. (0.017s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction5.mp4
# Out:
# detect: weights=['runs/train/hardhat_results37/weights/best.pt'], source=./video/construction5.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# video 1/1 (1/3746) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction5.mp4: 672x1280 1 helmet, Done. (0.025s)
# video 1/1 (2/3746) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction5.mp4: 672x1280 1 helmet, Done. (0.023s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction6.mp4
# Out:
# detect: weights=['runs/train/hardhat_results37/weights/best.pt'], source=./video/construction6.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# video 1/1 (1/4802) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction6.mp4: 672x1280 1 helmet, Done. (0.025s)
# video 1/1 (2/4802) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction6.mp4: 672x1280 1 helmet, Done. (0.023s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results2/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction7.mp4
# Out:
# detect: weights=['runs/train/hardhat_results37/weights/best.pt'], source=./video/construction7.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# video 1/1 (1/3201) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction7.mp4: 672x1280 1 helmet, Done. (0.025s)
# video 1/1 (2/3201) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/construction7.mp4: 672x1280 1 helmet, Done. (0.023s)
# ...

# %%
# !python detect.py --weights yolov5x.pt --img 1280 --conf 0.4 --source ./video/Thor.mp4
# Out:
# detect: weights=['yolov5x.pt'], source=./video/Thor.mp4, imgsz=[1280, 1280], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-12 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...
# 100% 166M/166M [00:01<00:00, 103MB/s]
#
# Fusing layers...
# Model Summary: 444 layers, 86705005 parameters, 0 gradients
# video 1/1 (1/1604) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/Thor.mp4: 608x1280 Done. (0.066s)
# video 1/1 (2/1604) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/Thor.mp4: 608x1280 Done. (0.062s)
# video 1/1 (3/1604) /content/drive/My Drive/Colab Notebooks/Yolo/yolov5/video/Thor.mp4: 608x1280 Done. (0.063s)
# ...

# %%
# !python detect.py --weights runs/train/hardhat_results/weights/best.pt --img 1280 --conf 0.4 --source ./video/construction1.mp4
